# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cd \Users\Gomu\Downloads
# Out:
# C:\Users\Gomu\Downloads

# %%
pwd
# Out:
# 'C:\\Users\\Gomu\\Downloads'

# %%
df = pd.read_csv("IT Companies 2000 To 2021 24 Variables.csv")
df.head()
# Out:
#                             Company Name  2000-PAT as % of net worth  \
# 0                24/7 Customer Pvt. Ltd.                         NaN
# 1                  3 K Technologies Ltd.                         NaN
# 2     3D P L M Global Services Pvt. Ltd.                         NaN
# 3                 3I Infotech B P O Ltd.                         NaN
# 4  3I Infotech Consultancy Services Ltd.                         NaN
#
#    2000-Return on capital employed  2000-PAT as % of total income  \
# 0                              NaN                            NaN
# 1                              NaN                            NaN
# 2                              NaN                            NaN
# 3                              NaN                            NaN
# 4                              NaN                            NaN
#
#    2000-Net Interest Margin (NIM) (%)  \
# 0                                 NaN
# 1                                 NaN
# ...

# %%
df.isnull().sum()
# Out:
# Company Name                             1
# 2000-PAT as % of net worth            1565
# 2000-Return on capital employed       1564
# 2000-PAT as % of total income         1539
# 2000-Net Interest Margin (NIM) (%)    1775
#                                       ...
# P/B.19                                1718
# EPS.19                                1718
# Yield.19                              1718
# Acquired                                 0
# date                                  1434
# Length: 531, dtype: int64

# %%
for i in range(len(df.index)) :
    print("Missing Values in Row -", i , ":" ,  df.iloc[i].isnull().sum())
# Out:
# Missing Values in Row - 0 : 355
# Missing Values in Row - 1 : 458
# Missing Values in Row - 2 : 417
# Missing Values in Row - 3 : 312
# Missing Values in Row - 4 : 310
# Missing Values in Row - 5 : 224
# Missing Values in Row - 6 : 105
# Missing Values in Row - 7 : 491
# Missing Values in Row - 8 : 248
# Missing Values in Row - 9 : 184
# Missing Values in Row - 10 : 440
# Missing Values in Row - 11 : 423
# Missing Values in Row - 12 : 529
# Missing Values in Row - 13 : 455
# Missing Values in Row - 14 : 439
# Missing Values in Row - 15 : 529
# Missing Values in Row - 16 : 381
# Missing Values in Row - 17 : 436
# Missing Values in Row - 18 : 528
# Missing Values in Row - 19 : 475
# Missing Values in Row - 20 : 412
# Missing Values in Row - 21 : 499
# Missing Values in Row - 22 : 407
# Missing Values in Row - 23 : 341
# Missing Values in Row - 24 : 370
# Missing Values in Row - 25 : 391
# Missing Values in Row - 26 : 206
# Missing Values in Row - 27 : 386
# ...

# %%
print(df.describe())
# Out:
#        PAT as % of net worth  Return on capital employed  \
# count             210.000000                  211.000000
# mean               25.107190                   19.559953
# std                36.164054                   23.603973
# min               -10.280000                   -3.890000
# 25%                 3.812500                    3.065000
# 50%                17.090000                   13.660000
# 75%                34.952500                   26.735000
# max               341.180000                  181.310000
#
#        PAT as % of total income  Net Interest Margin (NIM) (%)  \
# count                236.000000                            0.0
# mean                  17.685212                            NaN
# std                   16.903025                            NaN
# min                  -26.890000                            NaN
# 25%                    5.297500                            NaN
# 50%                   14.615000                            NaN
# ...

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(100, 23), columns=['2000-PAT as % of net worth','000-Return on capital employed','2000-PAT as % of total income	2000-Net Interest Margin (NIM) (%)','2000-Operating profit margin of non-financial companies','2000-Return on total assets','2000-Sales','2000-No. of employees','2000-Total Assets','2000-cf_net_frm_op_activity / total_assets','2000-Quick ratio (times)','2000-Current ratio (times)','2000-growth(sales,prevy(sales))','2000-sales/avg_networth','2000-sales/avg_capital_employed','2000-PBT as % of total income','2000-Debt to equity ratio (times)','2000-Interest cover (times)','2000-bse_market_cap/ paidup_equity_cap','2000-Market Capitalisation','2000-P/E','2000-P/B','2000-EPS','2000-Yield'])
df.plot.box(grid='True')
# Out:
# C:\Users\Gomu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Gomu\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)
