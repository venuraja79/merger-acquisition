# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cd \Users\Gomu\Downloads
# Out:
# C:\Users\Gomu\Downloads

# %%
pwd
# Out:
# 'C:\\Users\\Gomu\\Downloads'

# %%
df = pd.read_csv("IT Companies 2000 To 2021 24 Variables.csv")
df.head()
# Out:
#                             Company Name  2000-PAT as % of net worth  \
# 0                24/7 Customer Pvt. Ltd.                         NaN
# 1                  3 K Technologies Ltd.                         NaN
# 2     3D P L M Global Services Pvt. Ltd.                         NaN
# 3                 3I Infotech B P O Ltd.                         NaN
# 4  3I Infotech Consultancy Services Ltd.                         NaN
#
#    2000-Return on capital employed  2000-PAT as % of total income  \
# 0                              NaN                            NaN
# 1                              NaN                            NaN
# 2                              NaN                            NaN
# 3                              NaN                            NaN
# 4                              NaN                            NaN
#
#    2000-Net Interest Margin (NIM) (%)  \
# 0                                 NaN
# 1                                 NaN
# ...

# %%
df.isnull().sum()
# Out:
# Company Name                             1
# 2000-PAT as % of net worth            1565
# 2000-Return on capital employed       1564
# 2000-PAT as % of total income         1539
# 2000-Net Interest Margin (NIM) (%)    1775
#                                       ...
# 2021-P/B                              1718
# 2021-EPS                              1718
# 2021-Yield                            1718
# Acquired                                 0
# date                                  1434
# Length: 531, dtype: int64

# %%
for i in range(len(df.index)) :
    print("Missing Values in Row -", i , ":" ,  df.iloc[i].isnull().sum())
# Out:
# Missing Values in Row - 0 : 355
# Missing Values in Row - 1 : 458
# Missing Values in Row - 2 : 417
# Missing Values in Row - 3 : 312
# Missing Values in Row - 4 : 310
# Missing Values in Row - 5 : 224
# Missing Values in Row - 6 : 105
# Missing Values in Row - 7 : 491
# Missing Values in Row - 8 : 248
# Missing Values in Row - 9 : 184
# Missing Values in Row - 10 : 440
# Missing Values in Row - 11 : 423
# Missing Values in Row - 12 : 529
# Missing Values in Row - 13 : 455
# Missing Values in Row - 14 : 439
# Missing Values in Row - 15 : 529
# Missing Values in Row - 16 : 381
# Missing Values in Row - 17 : 436
# Missing Values in Row - 18 : 528
# Missing Values in Row - 19 : 475
# Missing Values in Row - 20 : 412
# Missing Values in Row - 21 : 499
# Missing Values in Row - 22 : 407
# Missing Values in Row - 23 : 341
# Missing Values in Row - 24 : 370
# Missing Values in Row - 25 : 391
# Missing Values in Row - 26 : 206
# Missing Values in Row - 27 : 386
# ...

# %%
print(df.describe())
# Out:
#        2000-PAT as % of net worth  2000-Return on capital employed  \
# count                  210.000000                       211.000000
# mean                    25.107190                        19.559953
# std                     36.164054                        23.603973
# min                    -10.280000                        -3.890000
# 25%                      3.812500                         3.065000
# 50%                     17.090000                        13.660000
# 75%                     34.952500                        26.735000
# max                    341.180000                       181.310000
#
#        2000-PAT as % of total income  2000-Net Interest Margin (NIM) (%)  \
# count                     236.000000                                 0.0
# mean                       17.685212                                 NaN
# std                        16.903025                                 NaN
# ...

# %%
dfY = df[df['Acquired '] == 'Y']
dfN = df[df['Acquired '] == 'N']

# %%
dfY.head()
# Out:
#                                    Company Name  2000-PAT as % of net worth  \
# 5                              3I Infotech Ltd.                       52.63
# 6                    63 Moons Technologies Ltd.                       25.24
# 8       A B B Global Inds. & Services Pvt. Ltd.                         NaN
# 18                             A H A Parks Ltd.                         NaN
# 22  A O K In-House B P O Services Ltd. [Merged]                         NaN
#
#     2000-Return on capital employed  2000-PAT as % of total income  \
# 5                             15.42                          25.26
# 6                             23.59                          31.28
# 8                               NaN                            NaN
# 18                              NaN                            NaN
# 22                              NaN                            NaN
#
#     2000-Net Interest Margin (NIM) (%)  \
# 5                                  NaN
# ...

# %%
dfN.head()
# Out:
#                             Company Name  2000-PAT as % of net worth  \
# 0                24/7 Customer Pvt. Ltd.                         NaN
# 1                  3 K Technologies Ltd.                         NaN
# 2     3D P L M Global Services Pvt. Ltd.                         NaN
# 3                 3I Infotech B P O Ltd.                         NaN
# 4  3I Infotech Consultancy Services Ltd.                         NaN
#
#    2000-Return on capital employed  2000-PAT as % of total income  \
# 0                              NaN                            NaN
# 1                              NaN                            NaN
# 2                              NaN                            NaN
# 3                              NaN                            NaN
# 4                              NaN                            NaN
#
#    2000-Net Interest Margin (NIM) (%)  \
# 0                                 NaN
# 1                                 NaN
# ...

# %%
len(dfN)
# Out:
# 1434

# %%
len(dfY)
# Out:
# 341

# %%
nw0=dfN['2000-PAT as % of net worth'].mean()
nw1=dfN['2001-PAT as % of net worth'].mean()
nw2=dfN['2002-PAT as % of net worth'].mean()
nw3=dfN['2003-PAT as % of net worth'].mean()
nw4=dfN['2004-PAT as % of net worth'].mean()
nw5=dfN['2005-PAT as % of net worth'].mean()
nw6=dfN['2006-PAT as % of net worth'].mean()
nw7=dfN['2007-PAT as % of net worth'].mean()
nw8=dfN['2008-PAT as % of net worth'].mean()
nw9=dfN['2009-PAT as % of net worth'].mean()
nw10=dfN['2010-PAT as % of net worth'].mean()
nw11=dfN['2011-PAT as % of net worth'].mean()
nw12=dfN['2012-PAT as % of net worth'].mean()
nw13=dfN['2013-PAT as % of net worth'].mean()
nw14=dfN['2014-PAT as % of net worth'].mean()
nw15=dfN['2015-PAT as % of net worth'].mean()
nw16=dfN['2016-PAT as % of net worth'].mean()
nw17=dfN['2017-PAT as % of net worth'].mean()
nw18=dfN['2018-PAT as % of net worth'].mean()
nw19=dfN['2019-PAT as % of net worth'].mean()
nw20=dfN['2020-PAT as % of net worth'].mean()
nw21=dfN['2021-PAT as % of net worth'].mean()
nwy0=dfY['2000-PAT as % of net worth'].mean()
nwy1=dfY['2001-PAT as % of net worth'].mean()
nwy2=dfY['2002-PAT as % of net worth'].mean()
nwy3=dfY['2003-PAT as % of net worth'].mean()
nwy4=dfY['2004-PAT as % of net worth'].mean()
nwy5=dfY['2005-PAT as % of net worth'].mean()
nwy6=dfY['2006-PAT as % of net worth'].mean()
nwy7=dfY['2007-PAT as % of net worth'].mean()
nwy8=dfY['2008-PAT as % of net worth'].mean()
nwy9=dfY['2009-PAT as % of net worth'].mean()
nwy10=dfY['2010-PAT as % of net worth'].mean()
nwy11=dfY['2011-PAT as % of net worth'].mean()
nwy12=dfY['2012-PAT as % of net worth'].mean()
nwy13=dfY['2013-PAT as % of net worth'].mean()
nwy14=dfY['2014-PAT as % of net worth'].mean()
nwy15=dfY['2015-PAT as % of net worth'].mean()
nwy16=dfY['2016-PAT as % of net worth'].mean()
nwy17=dfY['2017-PAT as % of net worth'].mean()
nwy18=dfY['2018-PAT as % of net worth'].mean()
nwy19=dfY['2019-PAT as % of net worth'].mean()
nwy20=dfY['2020-PAT as % of net worth'].mean()
nwy21=dfY['2021-PAT as % of net worth'].mean()

# %%
s = pd.Series([nw0,nw1,nw2,nw3,nw4,nw5,nw6,nw7,nw8,nw9,nw10,nw11,nw12,nw13,nw14,nw15,nw16,nw17,nw18,nw19,nw20,nw21])
s.plot.line()

# %%
s = pd.Series([nwy0,nwy1,nwy2,nwy3,nwy4,nwy5,nwy6,nwy7,nwy8,nwy9,nwy10,nwy11,nwy12,nwy13,nwy14,nwy15,nwy16,nwy17,nwy18,nwy19,nwy20,nwy21])
s.plot.line()
